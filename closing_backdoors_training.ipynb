# %% [markdown]
# <a href="https://colab.research.google.com/github/KingTechnician/shared-truth/blob/main/closing_backdoors_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bitsandbytes

# %%
# !git clone https://github.com/KingTechnician/Closing-Backdoors-Via-Representation-Transfer.git

import sys
sys.path.append('/content/Closing-Backdoors-Via-Representation-Transfer')

# %%
import os
from google.colab import userdata

os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")

# %%
# Needed for Colab, otherwise point to directory of repo
#%cd /content/Closing-Backdoors-Via-Representation-Transfer

# %%
# !python representation_transfer/main_optimized.py \
 --source_model_name "Qwen/Qwen2.5-7B-Instruct"\
 --target_model_name "mistralai/Mistral-7B-Instruct-v0.3" \
 --source_layer "model.layers.21" \
 --target_layer "model.layers.13" \
 --data_path "withmartian/code_backdoors_dev_prod_hh_rlhf_50percent" \
 --processed_data_path "processed_data.json" \
 --autoencoder_type "non_linear" \
 --hf_organization "KingTechnician" \
 --cross_architecture \
 --batch_size 8 \
 --monitor_interval 100 \
 --num_workers 4 \
 --gradient_accumulation_steps 4 \
 --max_length 720 \
 --lr 1e-4 \
 --num_epochs 3 \
 --val_split 0.1 \
 --project_name "qwen_2.5_7b_instruct_l21_to_mistral_7b_instruct_v0.3_l13"
